# %%
배열 = [-1, 1.5, "김보현"]
print(type(배열[2]))
"""*drive 폴더 새로 만들고 설정 더보기 콜라보레이터리
(구글에서 컴퓨터 빌려주는 거임)
print("hello world")
print(문자)를 에러가 안뜨게 출력하는 2가지 방법
붙이기
문자에다가 값 넣기
ex)문자 = 10
    문자 = "안녕하세요"
문자="안녕하세요"
print(문자)
안녕하세요

위에서 문자는 문자열이지만 따움표를 안 붙이는 이유: 문자열이지만 print가 문자열
출력이 아닌 변수 출력으로 취급해서 따움표를 안 붙임.

주석 : #
"를 출력하고 싶을때 "\"" 
"은 문자열이니 "로 감싸주고 \를 침으로써 이건 특정 기능을 수행하기 위한 것이
아닌 출력을 위한 따움 표다 라는것을 알려줌(다른거에도 사용 가능)\
응용:\"('.')"/ print로 출력해보기

\b: 백 스페이스(지우기)
\n: 개행(줄 바꾸기)
\t: 탭(큰 띄어쓰기)
print는 sep(separate:분리된)값을 기본적으로 " "을 가지고 있어서 여러개 출력할떄
자동으로 띄어쓰기가 댐
ex)print("데이터1", "데이터2", "데이터3")
   데이터1 데이터2 데이터3
,가 분리 되었는지 아닌지에 기준이 됨
우리가 sep=으로 바꿀 수 있음
end=을 통해 프린트 맨 마지막 끝에다가 원하는거 넣을 수 있음
활용:print(전화번호1,전화번호2,전화번호3)
을 통해 
010-2310-3085 똑같이 출력하기
숫자 출력할때 0이 처음에 오면 몇 진수인지 써 줘야함
why?우리가 일상생활에서는 0을 앞에 쓰진 않으니 앞에 쓸 경우 컴퓨터는
진수가 먼지 알려주려는 구나 라고 생각함 근데 01이라는 진수는 존재하지 않으니
오류 출력
0o(8진수), 0b(2진수), 0x(16진수)

/ : 나누기, 소숫점까지 나눔
//: 나누기, 정수자리만 출력(몫)
ex) 9/2 = 4.5
     9//2= 4
**:제곱
ex) 2**3 = 2x2x2 = 8
%:나머지
ex)
15%10 = 5


변수가 어떤 자료형인지 알고싶을때 :  type()

'문자열'끼리 사칙연산이 댐
문자열끼리 사칙연산하여 출력했을때 서로 띄어쓰기가 안 되어있음 = 두 문자열은 합쳐진거니까
하나 취급을 함
ex)
이름 = "김보현"
인사 ="안녕하세요"
print(이름, 인사)
김보현 안녕하세요

이름 = "김보현"
인사 ="안녕하세요"
print(이름+인사)
김보현안녕하세요
곱하기 등등도 통용댐
len():문자열의 길이를 출력해줌 
ex)
이름 = "김보현"
len(이름)
print(len)
3

문자열(리스트)
[]안에 ,로 구분하여 변수 여러개를 연속적으로 할당함
ex)
[1,2,3,4]
배열 = [-1, 10.5, '김보현', [1, 2, 3]]
자료형은 알빠가 아님
배열을 쓰는 이유: 배열은 순서가 있음
print(배열[0])
-1
컴퓨터는 숫자를 1부터 세는개 아닌 0부터샘
배열[0] : 배열의 0번째 값
print(배열[3])
[1,2,3]
print(배열[3][1])    다차원 배열(2차원 배열)
2
len(배열)
4
활용:무슨 배열을 출력하든 배열의 맨 마지막 값을 출력시켜 보아라
배열중 내가 원하는 부분만 출력하고 싶다: 리스트 슬라이싱
print(배열[1:3]) 첫번째 배열부터 3번째 배열 전 까지 
[10,2,'이름']
배열[:] : 전체를 의미함
배열[:][-1] = 3
해도 바뀌지 않음
why? [-1]은 배열에서 맨 마지막 값을 쓰는거지만
[:]은 그 값을 복사 하여서 쓰는거임 따라서 [:]을 써서 바꾸면 그 값이 원본에는
영향을 끼치지 않음
"""
# Out:
# <class 'str'>

# %%
전화번호="01056960763"

print((len(전화번호)-4)*"*"+전화번호[-4:])
# Out:
# *******0763
